# %% [markdown]
# <a href="https://colab.research.google.com/github/imfreeman1/StartGitHubDeskTop/blob/main/%5BE_03%5DCat_nose.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import cv2
import matplotlib.pyplot as plt
import numpy as np
import dlib
from google.colab import drive
drive.mount('/content/drive')

print("🌫🛸")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 🌫🛸

# %%
my_image_path = '/content/drive/MyDrive/제목없는 폴더/image2.png'
img_bgr = cv2.imread(my_image_path)    # OpenCV로 이미지를 불러옵니다
img_show = img_bgr.copy()      # 출력용 이미지를 따로 보관합니다
plt.imshow(img_bgr)
plt.show()

# %%
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.show()

# %%
detector_hog = dlib.get_frontal_face_detector()
print("🌫🛸")
# Out:
# 🌫🛸

# %%
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
dlib_rects = detector_hog(img_rgb, 2)   # (image, num of image pyramid)
print("🌫🛸")
# Out:
# 🌫🛸

# %%
print(dlib_rects)   

for dlib_rect in dlib_rects:
    l = dlib_rect.left()
    t = dlib_rect.top()
    r = dlib_rect.right()
    b = dlib_rect.bottom()

    cv2.rectangle(img_show, (l,t), (r,b), (0,255,0), 2, lineType=cv2.LINE_AA)

img_show_rgb =  cv2.cvtColor(img_show, cv2.COLOR_BGR2RGB)
plt.imshow(img_show_rgb)
plt.show()
# Out:
# rectangles[[(361, 102) (693, 435)]]

# %%
model_path = '/content/drive/MyDrive/제목없는 폴더/shape_predictor_68_face_landmarks.dat'
landmark_predictor = dlib.shape_predictor(model_path)
print("🌫🛸")
# Out:
# 🌫🛸

# %%
list_landmarks = []

# 얼굴 영역 박스 마다 face landmark를 찾아냅니다
for dlib_rect in dlib_rects:
    points = landmark_predictor(img_rgb, dlib_rect)
    # face landmark 좌표를 저장해둡니다
    list_points = list(map(lambda p: (p.x, p.y), points.parts()))
    list_landmarks.append(list_points)

print(len(list_landmarks[0]))
# Out:
# 68

# %%
for landmark in list_landmarks:
    for point in landmark:
        cv2.circle(img_show, point, 2, (0, 255, 255), -1)

img_show_rgb = cv2.cvtColor(img_show, cv2.COLOR_BGR2RGB)
plt.imshow(img_show_rgb)
plt.show()

# %%
for dlib_rect, landmark in zip(dlib_rects, list_landmarks):
    print (landmark[30]) # 코의 index는 30 입니다
    x = landmark[30][0]
    y = landmark[30][1] - dlib_rect.height()//2
    w = h = dlib_rect.width()
    print ('(x,y) : (%d,%d)'%(x,y))
    print ('(w,h) : (%d,%d)'%(w,h))
# Out:
# (577, 263)
# (x,y) : (577,96)
# (w,h) : (333,333)

# %%
sticker_path = '/content/drive/MyDrive/제목없는 폴더/cat-whiskers.png'
img_sticker = cv2.imread(sticker_path) # 스티커 이미지를 불러옵니다
img_sticker = cv2.resize(img_sticker, (w,h))
out = img_sticker.copy()
out = 255 - out
print (out.shape)
# print(img_sticker.shape)
# Out:
# (333, 333, 3)

# %%
refined_x = (x - w // 2) - 16
refined_y = y
print ('(x,y) : (%d,%d)'%(refined_x, refined_y))
# Out:
# (x,y) : (395,96)

# %%
if refined_x < 0: 
    img_sticker = img_sticker[:, -refined_x:]
    refined_x = 0
if refined_y < 0:
    img_sticker = img_sticker[-refined_y:, :]
    refined_y = 0

print ('(x,y) : (%d,%d)'%(refined_x, refined_y))
# Out:
# (x,y) : (395,96)

# %%
sticker_area = img_show[refined_y:refined_y+out.shape[0], refined_x:refined_x+out.shape[1]]
img_show[refined_y:refined_y+out.shape[0], refined_x:refined_x+out.shape[1]] = \
    np.where(out==0,sticker_area,out).astype(np.uint8)
print("슝~")
# Out:
# 슝~

# %%
plt.imshow(cv2.cvtColor(img_show, cv2.COLOR_BGR2RGB))
plt.show()

# %%
sticker_area = img_bgr[refined_y:refined_y +out.shape[0], refined_x:refined_x+out.shape[1]]
img_bgr[refined_y:refined_y +out.shape[0], refined_x:refined_x+out.shape[1]] = \
    np.where(out==0,sticker_area,out).astype(np.uint8)
plt.imshow(cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB))
plt.show()
