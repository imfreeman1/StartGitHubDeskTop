# %%
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn import svm
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
wines = load_wine()
wines_data = wines.data
wines_label = wines.target
X_train, X_test, y_train, y_test = train_test_split(wines_data, 
                                                    wines_label, 
                                                    test_size=0.2, 
                                                    random_state=7)
print(wines_data.shape)
# Out:
# (178, 13)

# %%
decision_tree = DecisionTreeClassifier(random_state=11)
decision_tree.fit(X_train, y_train)
y_pred = decision_tree.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      1.00      0.88         7
#            1       0.89      0.94      0.91        17
#            2       1.00      0.75      0.86        12
#
#     accuracy                           0.89        36
#    macro avg       0.89      0.90      0.88        36
# weighted avg       0.90      0.89      0.89        36

# %%
Random_Forest = RandomForestClassifier(random_state=11)
Random_Forest.fit(X_train, y_train)
y_pred_rf = Random_Forest.predict(X_test)

print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         7
#            1       1.00      1.00      1.00        17
#            2       1.00      1.00      1.00        12
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36

# %%
svm_model = svm.SVC()
svm_model.fit(X_train, y_train)
y_pred_svm = svm_model.predict(X_test)

print(classification_report(y_test, y_pred_svm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86         7
#            1       0.58      0.88      0.70        17
#            2       0.33      0.08      0.13        12
#
#     accuracy                           0.61        36
#    macro avg       0.59      0.61      0.56        36
# weighted avg       0.55      0.61      0.54        36

# %%
sgd_model = SGDClassifier()
sgd_model.fit(X_train, y_train)
y_pred_sgd = sgd_model.predict(X_test)

print(classification_report(y_test, y_pred_sgd))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.71      0.83         7
#            1       0.86      0.35      0.50        17
#            2       0.46      0.92      0.61        12
#
#     accuracy                           0.61        36
#    macro avg       0.77      0.66      0.65        36
# weighted avg       0.75      0.61      0.60        36

# %%
logistic_model = LogisticRegression(max_iter=10000)
logistic_model.fit(X_train, y_train)
y_pred_log = logistic_model.predict(X_test)

print(classification_report(y_test, y_pred_log))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         7
#            1       0.94      1.00      0.97        17
#            2       1.00      0.92      0.96        12
#
#     accuracy                           0.97        36
#    macro avg       0.98      0.97      0.98        36
# weighted avg       0.97      0.97      0.97        36

# %% [markdown]
# 와인
# 실제 참인 결과값이 거짓으로 판명되는 경우가 추가 검사를 통해 재검토가 가능하기 때문에 precision으로 확인하는 것이 좋다.
# Recall값이 높은 DecisionTreeClassifier, LogisticRegression, RandomForestClassifier의 모델이 적합성이 높아보인다.
